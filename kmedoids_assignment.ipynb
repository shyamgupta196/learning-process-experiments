# %%
pip install scikit-learn-extra
# Out:
# Requirement already satisfied: scikit-learn-extra in /usr/local/lib/python3.6/dist-packages (0.1.0b2)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from scikit-learn-extra) (1.18.5)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.6/dist-packages (from scikit-learn-extra) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.21.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn-extra) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.21.0->scikit-learn-extra) (0.17.0)

# %%
'''
@author=='shyamgupta196
python version used==3.8.3
'''
# Out:
# "\n@author=='shyamgupta196\npython version used==3.8.3\n"

# %% [markdown]
# ### the motivation behind the study is to know how people are facing heart problems

# %% [markdown]
# ###### in this we are interested in knowing what is can be the relation of the rising cholestrol level with different features of the data

# %%
from sklearn_extra.cluster import KMedoids 
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('heart.csv')

# %% [markdown]
# #### we check for the values of the serum cholestoral in mg/dl
#  ### ('chol') column

# %%
sns.distplot(df[['chol']])

# %% [markdown]
# ##### as we can see that although the values are distributed uniformly the data is having the distribution over a long range of values

# %% [markdown]
# ##### therefore we use standard scalar to scale the values of the data

# %%
df['chol'] = StandardScaler().fit_transform(df['chol'].values.reshape(-1,1))

# %%
# df = pd.DataFrame(scale,columns=df.columns)

# %%
sns.distplot(df[['chol']])

# %% [markdown]
# ###### finding the best value for no of clusters in the 'chol' column

# %%
inertias = []
for i in range(1,10):
  km = KMedoids(i)
  preds = km.fit(df[['chol']])
  inertias.append(km.inertia_)

# %% [markdown]
# #### using elbow method to find the number of clusters with least SSE

# %%
plt.plot(inertias)

# %% [markdown]
# ### looks like 5 is value of clusters we were looking at so lets use that

# %%
km = KMedoids(5).fit(df[['chol']])

# %%
x=df[['chol']]

preds = km.predict(x)
print(preds)
df['predictions_chol'] = preds
# df.set_index('predictions_thalach',inplace=True)
# Out:
# [2 3 0 3 4 0 4 1 0 0 3 1 1 2 1 2 4 2 3 3 2 2 2 3 0 4 2 0 4 0 0 0 2 1 2 0 4
#  2 1 4 4 3 0 1 4 4 2 3 2 2 3 4 2 0 3 0 2 1 0 4 1 4 0 0 2 0 2 2 2 0 3 2 0 1
#  2 3 3 2 0 3 3 4 4 4 1 4 1 0 2 3 3 0 2 1 0 2 4 2 4 3 3 1 0 3 0 2 2 3 3 3 4
#  0 4 2 1 2 2 0 0 3 4 1 1 1 0 0 0 1 0 1 0 1 4 2 4 1 0 0 0 1 4 4 0 2 0 3 3 3
#  2 0 2 0 2 1 2 0 3 0 2 2 3 4 0 0 0 1 2 1 3 0 3 2 1 2 0 0 2 4 0 1 4 2 4 2 3
#  1 3 1 2 0 4 2 0 1 0 4 2 3 1 3 0 3 1 1 0 3 3 3 0 0 2 1 2 4 3 4 1 4 3 3 4 2
#  1 1 3 0 1 0 1 4 3 1 1 3 4 4 4 4 4 1 1 3 2 1 0 1 4 3 1 3 4 3 4 4 1 4 1 0 3
#  2 2 2 1 1 0 2 4 0 1 1 3 2 3 2 1 2 2 1 4 0 4 0 2 2 0 4 0 2 4 0 0 4 2 2 0 0
#  0 0 3 1 0 0 3]

# %%
center = km.cluster_centers_
print(center)
# Out:
# [[-0.95205107]
#  [ 0.47803462]
#  [-0.41093757]
#  [-0.00510244]
#  [ 1.28970488]]

# %%
df5 = df[df.predictions_chol==4]
df4 = df[df.predictions_chol==3]
df3 = df[df.predictions_chol==2]
df2 = df[df.predictions_chol==1]
df1 = df[df.predictions_chol==0]

# plt.plot(center[0][0],marker='*',color='black',label='cluster centers')
# plt.plot(center[1][0],marker='*',color='black')
# plt.plot(center[2][0],marker='*',color='black')
# plt.plot(center[3][0],marker='*',color='black')
# plt.plot(center[4][0],marker='*',color='black')


# since the cluster values are very low n 1-D data so we cannot use them for plotting

fig = plt.figure(figsize=(20,14))

ax1 =  fig.add_subplot(221)
ax1.scatter(x=df1.predictions_chol,y=df1.fbs,label='0 level',)
ax1.scatter(x=df2.predictions_chol,y=df2.fbs,label='1 level')
ax1.scatter(x=df3.predictions_chol,y=df3.fbs,label='2 level')
ax1.scatter(x=df4.predictions_chol,y=df4.fbs,label='3 level')
ax1.scatter(x=df5.predictions_chol,y=df5.fbs,label='4 level')
ax1.set_xlabel('chol')
ax1.set_ylabel('fasting blood sugar')

ax2 = fig.add_subplot(222)

ax2.scatter(x=df1.predictions_chol,y=df1.age,label='0 level',)
ax2.scatter(x=df2.predictions_chol,y=df2.age,label='1 level')
ax2.scatter(x=df3.predictions_chol,y=df3.age,label='2 level')
ax2.scatter(x=df4.predictions_chol,y=df4.age,label='3 level')
ax2.scatter(x=df5.predictions_chol,y=df5.age,label='4 level')
ax2.set_xlabel('chol')
ax2.set_ylabel('AGE GROUPS OF PEOPLE')

ax3 = fig.add_subplot(223)

ax3.scatter(x=df1.predictions_chol,y=df1.thalach,label='0 level',)
ax3.scatter(x=df2.predictions_chol,y=df2.thalach,label='1 level')
ax3.scatter(x=df3.predictions_chol,y=df3.thalach,label='2 level')
ax3.scatter(x=df4.predictions_chol,y=df4.thalach,label='3 level')
ax3.scatter(x=df5.predictions_chol,y=df5.thalach,label='4 level')
ax3.set_xlabel('chol')
ax3.set_ylabel('maximum heart rate achieved')

ax4 = fig.add_subplot(224)

ax4.scatter(x=df1.predictions_chol,y=df1.oldpeak,label='0 level',)
ax4.scatter(x=df2.predictions_chol,y=df2.oldpeak,label='1 level')
ax4.scatter(x=df3.predictions_chol,y=df3.oldpeak,label='2 level')
ax4.scatter(x=df4.predictions_chol,y=df4.oldpeak,label='3 level')
ax4.scatter(x=df5.predictions_chol,y=df5.oldpeak,label='4 level')
ax4.set_xlabel('chol')
ax4.set_ylabel('depression induced by excercise related to rest')


plt.legend()
plt.show()

# %% [markdown]
# ### due to lack of domain knowledge we do not know what levels are having what risk factor associated with it
# ##### but one thing that can be seen clearly is the seperation of people n done correctly and they are placed correctly in respective clusters
# ##### this can be validated by seeing its relation with different columns

# %% [markdown]
# ### thank you
